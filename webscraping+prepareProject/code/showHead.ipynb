# %%
import pandas as pd

df1 = pd.read_excel("allCat.xlsx")
df2 = pd.read_excel("cleaned_architect-engineer.xlsx")

# %%
df1.head()
# Out:
#   Unnamed: 0        summary 9 หมวด    Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0        No.                  หมวด  status scarp   sub หมวด  จำนวน page
# 1          1          ออกแบบกราฟิก            ok         29         408
# 2          2       การตลาดและโฆษณา            ok         21         102
# 3          3  เว็บไซต์และเทคโนโลยี            ok         18          97
# 4          4       ไลฟ์สไตล์ (ซัน)   ยังไม่ได้ทำ         14          41
#
#             Unnamed: 5                                         Unnamed: 6  \
# 0          scarp เมื่อ                                        ลิงค์ข้อมูล
# 1         11-12/6/2024  https://docs.google.com/spreadsheets/d/1QAArQX...
# 2         13-14/6/2024  https://docs.google.com/spreadsheets/d/1diaRTm...
# 3  2024-06-13 00:00:00  https://docs.google.com/spreadsheets/d/1HD5G1l...
# 4                  NaN                                                NaN
#
#                                           Unnamed: 7  \
# ...

# %%
df2.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1718528605-1  https://fastwork.co/home-inspection?source=cat...
# 1      1718528607-2  https://fastwork.co/home-inspection?source=cat...
# 2      1718528609-3  https://fastwork.co/home-inspection?source=cat...
# 3      1718528611-4  https://fastwork.co/home-inspection?source=cat...
# 4      1718528614-5  https://fastwork.co/home-inspection?source=cat...
#
#                                                title  rating_comment  \
# 0  ตรวจรับบ้านและคอนโดก่อนโอน โดยวิศวกรโยธา ระดับ...             0.0
# 1  บริการให้คำปรึกษาพร้อมรับตรวจคอนโดโดยวิศวกรที่...             0.0
# 2  แว่นขยาย บริการตรวจ defect ก่อนโอน โดยสถาปนิกแ...             0.0
# 3  ตรวจคอนโด ตรวจบ้าน ตรวจอาคารพาณิชย์ ด้วยทีมงาน...             0.0
# 4  ตรวจรับบ้านและคอนโด ตรวจสอบขั้นตอนการก่อสร้างข...             0.0
#
#    Num_comment  cost                                               link  \
# ...
